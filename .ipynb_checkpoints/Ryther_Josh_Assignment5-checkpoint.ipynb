# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 16
# Scores: (min: 16, avg: 16, max: 16)
#
# Run: 2, exploration: 0.9511101304657719, score: 14
# Scores: (min: 14, avg: 15, max: 16)
#
# Run: 3, exploration: 0.9000874278732445, score: 12
# Scores: (min: 12, avg: 14, max: 16)
#
# Run: 4, exploration: 0.8265651079747222, score: 18
# Scores: (min: 12, avg: 15, max: 18)
#
# Run: 5, exploration: 0.7822236754458713, score: 12
# Scores: (min: 12, avg: 14.4, max: 18)
#
# Run: 6, exploration: 0.7219385759785162, score: 17
# Scores: (min: 12, avg: 14.833333333333334, max: 18)
#
# Run: 7, exploration: 0.6900935609921609, score: 10
# Scores: (min: 10, avg: 14.142857142857142, max: 18)
#
# Run: 8, exploration: 0.6596532430440636, score: 10
# Scores: (min: 10, avg: 13.625, max: 18)
#
# Run: 9, exploration: 0.6242658676435396, score: 12
# Scores: (min: 10, avg: 13.444444444444445, max: 18)
#
# Run: 10, exploration: 0.5907768628656763, score: 12
# Scores: (min: 10, avg: 13.3, max: 18)
#
# Run: 11, exploration: 0.5562889678716474, score: 13
# Scores: (min: 10, avg: 13.272727272727273, max: 18)
#
# Run: 12, exploration: 0.5264466124450268, score: 12
# Scores: (min: 10, avg: 13.166666666666666, max: 18)
#
# Run: 13, exploration: 0.4883155414435353, score: 16
# Scores: (min: 10, avg: 13.384615384615385, max: 18)
#
# Run: 14, exploration: 0.46677573701590436, score: 10
# Scores: (min: 10, avg: 13.142857142857142, max: 18)
#
# Run: 15, exploration: 0.43080185560799106, score: 17
# Scores: (min: 10, avg: 13.4, max: 18)
#
# Run: 16, exploration: 0.4016064652978155, score: 15
# Scores: (min: 10, avg: 13.5, max: 18)
#
# Run: 17, exploration: 0.38389143477919885, score: 10
# Scores: (min: 10, avg: 13.294117647058824, max: 18)
#
# Run: 18, exploration: 0.36512303261753626, score: 11
# Scores: (min: 10, avg: 13.166666666666666, max: 18)
#
# Run: 19, exploration: 0.34901730169741024, score: 10
# Scores: (min: 10, avg: 13, max: 18)
#
# Run: 20, exploration: 0.32864265128599696, score: 13
# Scores: (min: 10, avg: 13, max: 18)
#
# Run: 21, exploration: 0.31101247816653554, score: 12
# Scores: (min: 10, avg: 12.952380952380953, max: 18)
#
# Run: 22, exploration: 0.29285644267656924, score: 13
# Scores: (min: 10, avg: 12.954545454545455, max: 18)
#
# Run: 23, exploration: 0.28134514724562876, score: 9
# Scores: (min: 9, avg: 12.782608695652174, max: 18)
#
# Run: 24, exploration: 0.2689348941735696, score: 10
# Scores: (min: 9, avg: 12.666666666666666, max: 18)
#
# Run: 25, exploration: 0.2570720625972084, score: 10
# Scores: (min: 9, avg: 12.56, max: 18)
#
# Run: 26, exploration: 0.2457325055235537, score: 10
# Scores: (min: 9, avg: 12.461538461538462, max: 18)
#
# Run: 27, exploration: 0.23371867538818816, score: 11
# Scores: (min: 9, avg: 12.407407407407407, max: 18)
#
# Run: 28, exploration: 0.2041345879004775, score: 28
# Scores: (min: 9, avg: 12.964285714285714, max: 28)
#
# Run: 29, exploration: 0.12807462877562611, score: 94
# Scores: (min: 9, avg: 15.758620689655173, max: 94)
#
# Run: 30, exploration: 0.10533270926593409, score: 40
# Scores: (min: 9, avg: 16.566666666666666, max: 94)
#
# Run: 31, exploration: 0.0888276147181114, score: 35
# Scores: (min: 9, avg: 17.161290322580644, max: 94)
#
# Run: 32, exploration: 0.05517478773284426, score: 96
# Scores: (min: 9, avg: 19.625, max: 96)
#
# Run: 33, exploration: 0.04251487140556204, score: 53
# Scores: (min: 9, avg: 20.636363636363637, max: 96)
#
# Run: 34, exploration: 0.03359121130473201, score: 48
# Scores: (min: 9, avg: 21.441176470588236, max: 96)
#
# Run: 35, exploration: 0.026673952849996664, score: 47
# Scores: (min: 9, avg: 22.17142857142857, max: 96)
#
# Run: 36, exploration: 0.017595559502304726, score: 84
# Scores: (min: 9, avg: 23.88888888888889, max: 96)
#
# Run: 37, exploration: 0.01, score: 128
# Scores: (min: 9, avg: 26.7027027027027, max: 128)
#
# Run: 38, exploration: 0.01, score: 62
# Scores: (min: 9, avg: 27.63157894736842, max: 128)
#
# Run: 39, exploration: 0.01, score: 188
# Scores: (min: 9, avg: 31.743589743589745, max: 188)
#
# Run: 40, exploration: 0.01, score: 105
# Scores: (min: 9, avg: 33.575, max: 188)
#
# Run: 41, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 38.390243902439025, max: 231)
#
# Run: 42, exploration: 0.01, score: 232
# Scores: (min: 9, avg: 43, max: 232)
#
# Run: 43, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 47.16279069767442, max: 232)
#
# Run: 44, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 52.22727272727273, max: 270)
#
# Run: 45, exploration: 0.01, score: 375
# Scores: (min: 9, avg: 59.4, max: 375)
#
# Run: 46, exploration: 0.01, score: 384
# Scores: (min: 9, avg: 66.45652173913044, max: 384)
#
# Run: 47, exploration: 0.01, score: 239
# Scores: (min: 9, avg: 70.12765957446808, max: 384)
#
# Run: 48, exploration: 0.01, score: 222
# Scores: (min: 9, avg: 73.29166666666667, max: 384)
#
# Run: 49, exploration: 0.01, score: 279
# Scores: (min: 9, avg: 77.48979591836735, max: 384)
#
# Run: 50, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 80.98, max: 384)
#
# Run: 51, exploration: 0.01, score: 343
# Scores: (min: 9, avg: 86.11764705882354, max: 384)
#
# Run: 52, exploration: 0.01, score: 318
# Scores: (min: 9, avg: 90.57692307692308, max: 384)
#
# Run: 53, exploration: 0.01, score: 292
# Scores: (min: 9, avg: 94.37735849056604, max: 384)
#
# Run: 54, exploration: 0.01, score: 247
# Scores: (min: 9, avg: 97.20370370370371, max: 384)
#
# Run: 55, exploration: 0.01, score: 280
# Scores: (min: 9, avg: 100.52727272727273, max: 384)
#
# Run: 56, exploration: 0.01, score: 378
# Scores: (min: 9, avg: 105.48214285714286, max: 384)
#
# Run: 57, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 112.40350877192982, max: 500)
#
# Run: 58, exploration: 0.01, score: 326
# Scores: (min: 9, avg: 116.08620689655173, max: 500)
#
# Run: 59, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 118.49152542372882, max: 500)
#
# Run: 60, exploration: 0.01, score: 216
# Scores: (min: 9, avg: 120.11666666666666, max: 500)
#
# Run: 61, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 121.8688524590164, max: 500)
#
# Run: 62, exploration: 0.01, score: 244
# Scores: (min: 9, avg: 123.83870967741936, max: 500)
#
# Run: 63, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 126.58730158730158, max: 500)
#
# Run: 64, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 132.421875, max: 500)
#
# Run: 65, exploration: 0.01, score: 363
# Scores: (min: 9, avg: 135.96923076923076, max: 500)
#
# Run: 66, exploration: 0.01, score: 265
# Scores: (min: 9, avg: 137.92424242424244, max: 500)
#
# Run: 67, exploration: 0.01, score: 331
# Scores: (min: 9, avg: 140.80597014925374, max: 500)
#
# Run: 68, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 142.2058823529412, max: 500)
#
# Run: 69, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 143.44927536231884, max: 500)
#
# Run: 70, exploration: 0.01, score: 260
# Scores: (min: 9, avg: 145.11428571428573, max: 500)
#
# Run: 71, exploration: 0.01, score: 304
# Scores: (min: 9, avg: 147.35211267605635, max: 500)
#
# Run: 72, exploration: 0.01, score: 432
# Scores: (min: 9, avg: 151.30555555555554, max: 500)
#
# Run: 73, exploration: 0.01, score: 330
# Scores: (min: 9, avg: 153.75342465753425, max: 500)
#
# Run: 74, exploration: 0.01, score: 316
# Scores: (min: 9, avg: 155.94594594594594, max: 500)
#
# Run: 75, exploration: 0.01, score: 288
# Scores: (min: 9, avg: 157.70666666666668, max: 500)
#
# Run: 76, exploration: 0.01, score: 231
# Scores: (min: 9, avg: 158.67105263157896, max: 500)
#
# Run: 77, exploration: 0.01, score: 395
# Scores: (min: 9, avg: 161.74025974025975, max: 500)
#
# Run: 78, exploration: 0.01, score: 220
# Scores: (min: 9, avg: 162.48717948717947, max: 500)
#
# Run: 79, exploration: 0.01, score: 416
# Scores: (min: 9, avg: 165.69620253164558, max: 500)
#
# Run: 80, exploration: 0.01, score: 472
# Scores: (min: 9, avg: 169.525, max: 500)
#
# Run: 81, exploration: 0.01, score: 376
# Scores: (min: 9, avg: 172.07407407407408, max: 500)
#
# Run: 82, exploration: 0.01, score: 333
# Scores: (min: 9, avg: 174.03658536585365, max: 500)
#
# Run: 83, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 174.66265060240963, max: 500)
#
# Run: 84, exploration: 0.01, score: 397
# Scores: (min: 9, avg: 177.3095238095238, max: 500)
#
# Run: 85, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 177.88235294117646, max: 500)
#
# Run: 86, exploration: 0.01, score: 290
# Scores: (min: 9, avg: 179.1860465116279, max: 500)
#
# Run: 87, exploration: 0.01, score: 345
# Scores: (min: 9, avg: 181.09195402298852, max: 500)
#
# Run: 88, exploration: 0.01, score: 356
# Scores: (min: 9, avg: 183.07954545454547, max: 500)
# Run: 89, exploration: 0.01, score: 368
# Scores: (min: 9, avg: 185.1573033707865, max: 500)
#
# Run: 90, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 185.06666666666666, max: 500)
#
# Run: 91, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 186.47252747252747, max: 500)
#
# Run: 92, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 189.8804347826087, max: 500)
#
# Run: 93, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 190.74193548387098, max: 500)
#
# Run: 94, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 194.03191489361703, max: 500)
#
# Run: 95, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 197.25263157894736, max: 500)
#
# Run: 96, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 198.14583333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 201.2577319587629, max: 500)
#
# Run: 98, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 204.30612244897958, max: 500)
#
# Run: 99, exploration: 0.01, score: 311
# Scores: (min: 9, avg: 205.3838383838384, max: 500)
#
# Run: 100, exploration: 0.01, score: 423
# Scores: (min: 9, avg: 207.56, max: 500)
#
# Solved in 0 runs, 100 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
GAMMA = 0.90  
LEARNING_RATE = 0.01 

EXPLORATION_MAX = 2.0  
EXPLORATION_MIN = 0.05  
EXPLORATION_DECAY = 0.8

cartpole()
# Out:
# Run: 1, exploration: 2.0, score: 18
# Scores: (min: 18, avg: 18, max: 18)
#
# Run: 2, exploration: 0.056294995342131254, score: 18
# Scores: (min: 18, avg: 18, max: 18)
#
# Run: 3, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 15.333333333333334, max: 18)
#
# Run: 4, exploration: 0.05, score: 28
# Scores: (min: 10, avg: 18.5, max: 28)
#
# Run: 5, exploration: 0.05, score: 24
# Scores: (min: 10, avg: 19.6, max: 28)
#
# Run: 6, exploration: 0.05, score: 84
# Scores: (min: 10, avg: 30.333333333333332, max: 84)
#
# Run: 7, exploration: 0.05, score: 43
# Scores: (min: 10, avg: 32.142857142857146, max: 84)
#
# Run: 8, exploration: 0.05, score: 58
# Scores: (min: 10, avg: 35.375, max: 84)
#
# Run: 9, exploration: 0.05, score: 31
# Scores: (min: 10, avg: 34.888888888888886, max: 84)
#
# Run: 10, exploration: 0.05, score: 96
# Scores: (min: 10, avg: 41, max: 96)
#
# Run: 11, exploration: 0.05, score: 240
# Scores: (min: 10, avg: 59.09090909090909, max: 240)
#
# Run: 12, exploration: 0.05, score: 103
# Scores: (min: 10, avg: 62.75, max: 240)
#
# Run: 13, exploration: 0.05, score: 35
# Scores: (min: 10, avg: 60.61538461538461, max: 240)
#
# Run: 14, exploration: 0.05, score: 22
# Scores: (min: 10, avg: 57.857142857142854, max: 240)
#
# Run: 15, exploration: 0.05, score: 38
# Scores: (min: 10, avg: 56.53333333333333, max: 240)
#
# Run: 16, exploration: 0.05, score: 50
# Scores: (min: 10, avg: 56.125, max: 240)
#
# Run: 17, exploration: 0.05, score: 12
# Scores: (min: 10, avg: 53.529411764705884, max: 240)
#
# Run: 18, exploration: 0.05, score: 74
# Scores: (min: 10, avg: 54.666666666666664, max: 240)
#
# Run: 19, exploration: 0.05, score: 68
# Scores: (min: 10, avg: 55.36842105263158, max: 240)
#
# Run: 20, exploration: 0.05, score: 42
# Scores: (min: 10, avg: 54.7, max: 240)
#
# Run: 21, exploration: 0.05, score: 58
# Scores: (min: 10, avg: 54.857142857142854, max: 240)
#
# Run: 22, exploration: 0.05, score: 92
# Scores: (min: 10, avg: 56.54545454545455, max: 240)
#
# Run: 23, exploration: 0.05, score: 103
# Scores: (min: 10, avg: 58.56521739130435, max: 240)
#
# Run: 24, exploration: 0.05, score: 47
# Scores: (min: 10, avg: 58.083333333333336, max: 240)
#
# Run: 25, exploration: 0.05, score: 40
# Scores: (min: 10, avg: 57.36, max: 240)
#
# Run: 26, exploration: 0.05, score: 127
# Scores: (min: 10, avg: 60.03846153846154, max: 240)
#
# Run: 27, exploration: 0.05, score: 86
# Scores: (min: 10, avg: 61, max: 240)
#
# Run: 28, exploration: 0.05, score: 81
# Scores: (min: 10, avg: 61.714285714285715, max: 240)
#
# Run: 29, exploration: 0.05, score: 82
# Scores: (min: 10, avg: 62.41379310344828, max: 240)
#
# Run: 30, exploration: 0.05, score: 69
# Scores: (min: 10, avg: 62.63333333333333, max: 240)
#
# Run: 31, exploration: 0.05, score: 127
# Scores: (min: 10, avg: 64.70967741935483, max: 240)
#
# Run: 32, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 63, max: 240)
#
# Run: 33, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 61.36363636363637, max: 240)
#
# Run: 34, exploration: 0.05, score: 13
# Scores: (min: 9, avg: 59.94117647058823, max: 240)
#
# Run: 35, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 58.51428571428571, max: 240)
#
# Run: 36, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 57.19444444444444, max: 240)
#
# Run: 37, exploration: 0.05, score: 91
# Scores: (min: 9, avg: 58.108108108108105, max: 240)
#
# Run: 38, exploration: 0.05, score: 85
# Scores: (min: 9, avg: 58.81578947368421, max: 240)
#
# Run: 39, exploration: 0.05, score: 15
# Scores: (min: 9, avg: 57.69230769230769, max: 240)
#
# Run: 40, exploration: 0.05, score: 23
# Scores: (min: 9, avg: 56.825, max: 240)
#
# Run: 41, exploration: 0.05, score: 150
# Scores: (min: 9, avg: 59.09756097560975, max: 240)
#
# Run: 42, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 57.904761904761905, max: 240)
#
# Run: 43, exploration: 0.05, score: 79
# Scores: (min: 9, avg: 58.395348837209305, max: 240)
#
# Run: 44, exploration: 0.05, score: 42
# Scores: (min: 9, avg: 58.02272727272727, max: 240)
#
# Run: 45, exploration: 0.05, score: 12
# Scores: (min: 9, avg: 57, max: 240)
#
# Run: 46, exploration: 0.05, score: 139
# Scores: (min: 9, avg: 58.78260869565217, max: 240)
#
# Run: 47, exploration: 0.05, score: 27
# Scores: (min: 9, avg: 58.1063829787234, max: 240)
#
# Run: 48, exploration: 0.05, score: 37
# Scores: (min: 9, avg: 57.666666666666664, max: 240)
#
# Run: 49, exploration: 0.05, score: 69
# Scores: (min: 9, avg: 57.89795918367347, max: 240)
#
# Run: 50, exploration: 0.05, score: 159
# Scores: (min: 9, avg: 59.92, max: 240)
#
# Run: 51, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 58.96078431372549, max: 240)
#
# Run: 52, exploration: 0.05, score: 134
# Scores: (min: 9, avg: 60.40384615384615, max: 240)
#
# Run: 53, exploration: 0.05, score: 500
# Scores: (min: 9, avg: 68.69811320754717, max: 500)
#
# Run: 54, exploration: 0.05, score: 145
# Scores: (min: 9, avg: 70.11111111111111, max: 500)
#
# Run: 55, exploration: 0.05, score: 65
# Scores: (min: 9, avg: 70.01818181818182, max: 500)
#
# Run: 56, exploration: 0.05, score: 119
# Scores: (min: 9, avg: 70.89285714285714, max: 500)
#
# Run: 57, exploration: 0.05, score: 122
# Scores: (min: 9, avg: 71.78947368421052, max: 500)
#
# Run: 58, exploration: 0.05, score: 137
# Scores: (min: 9, avg: 72.91379310344827, max: 500)
#
# Run: 59, exploration: 0.05, score: 36
# Scores: (min: 9, avg: 72.28813559322033, max: 500)
#
# Run: 60, exploration: 0.05, score: 18
# Scores: (min: 9, avg: 71.38333333333334, max: 500)
#
# Run: 61, exploration: 0.05, score: 12
# Scores: (min: 9, avg: 70.40983606557377, max: 500)
#
# Run: 62, exploration: 0.05, score: 12
# Scores: (min: 9, avg: 69.46774193548387, max: 500)
#
# Run: 63, exploration: 0.05, score: 38
# Scores: (min: 9, avg: 68.96825396825396, max: 500)
#
# Run: 64, exploration: 0.05, score: 36
# Scores: (min: 9, avg: 68.453125, max: 500)
#
# Run: 65, exploration: 0.05, score: 105
# Scores: (min: 9, avg: 69.01538461538462, max: 500)
#
# Run: 66, exploration: 0.05, score: 153
# Scores: (min: 9, avg: 70.28787878787878, max: 500)
#
# Run: 67, exploration: 0.05, score: 96
# Scores: (min: 9, avg: 70.67164179104478, max: 500)
#
# Run: 68, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 69.77941176470588, max: 500)
#
# Run: 69, exploration: 0.05, score: 61
# Scores: (min: 9, avg: 69.65217391304348, max: 500)
#
# Run: 70, exploration: 0.05, score: 63
# Scores: (min: 9, avg: 69.55714285714286, max: 500)
#
# Run: 71, exploration: 0.05, score: 97
# Scores: (min: 9, avg: 69.94366197183099, max: 500)
#
# Run: 72, exploration: 0.05, score: 77
# Scores: (min: 9, avg: 70.04166666666667, max: 500)
#
# Run: 73, exploration: 0.05, score: 183
# Scores: (min: 9, avg: 71.58904109589041, max: 500)
#
# Run: 74, exploration: 0.05, score: 124
# Scores: (min: 9, avg: 72.29729729729729, max: 500)
#
# Run: 75, exploration: 0.05, score: 86
# Scores: (min: 9, avg: 72.48, max: 500)
#
# Run: 76, exploration: 0.05, score: 98
# Scores: (min: 9, avg: 72.8157894736842, max: 500)
#
# Run: 77, exploration: 0.05, score: 89
# Scores: (min: 9, avg: 73.02597402597402, max: 500)
#
# Run: 78, exploration: 0.05, score: 84
# Scores: (min: 9, avg: 73.16666666666667, max: 500)
#
# Run: 79, exploration: 0.05, score: 75
# Scores: (min: 9, avg: 73.18987341772151, max: 500)
#
# Run: 80, exploration: 0.05, score: 104
# Scores: (min: 9, avg: 73.575, max: 500)
#
# Run: 81, exploration: 0.05, score: 98
# Scores: (min: 9, avg: 73.87654320987654, max: 500)
#
# Run: 82, exploration: 0.05, score: 65
# Scores: (min: 9, avg: 73.76829268292683, max: 500)
#
# Run: 83, exploration: 0.05, score: 103
# Scores: (min: 9, avg: 74.12048192771084, max: 500)
#
# Run: 84, exploration: 0.05, score: 139
# Scores: (min: 9, avg: 74.89285714285714, max: 500)
#
# Run: 85, exploration: 0.05, score: 248
# Scores: (min: 9, avg: 76.92941176470588, max: 500)
#
# Run: 86, exploration: 0.05, score: 51
# Scores: (min: 9, avg: 76.62790697674419, max: 500)
#
# Run: 87, exploration: 0.05, score: 20
# Scores: (min: 9, avg: 75.97701149425288, max: 500)
#
# Run: 88, exploration: 0.05, score: 14
# Scores: (min: 9, avg: 75.27272727272727, max: 500)
#
# Run: 89, exploration: 0.05, score: 98
# Scores: (min: 9, avg: 75.52808988764045, max: 500)
#
# Run: 90, exploration: 0.05, score: 66
# Scores: (min: 9, avg: 75.42222222222222, max: 500)
#
# Run: 91, exploration: 0.05, score: 130
# Scores: (min: 9, avg: 76.02197802197803, max: 500)
#
# Run: 92, exploration: 0.05, score: 21
# Scores: (min: 9, avg: 75.42391304347827, max: 500)
#
# Run: 93, exploration: 0.05, score: 18
# Scores: (min: 9, avg: 74.80645161290323, max: 500)
# Run: 94, exploration: 0.05, score: 56
# Scores: (min: 9, avg: 74.6063829787234, max: 500)
#
# Run: 95, exploration: 0.05, score: 43
# Scores: (min: 9, avg: 74.27368421052631, max: 500)
#
# Run: 96, exploration: 0.05, score: 15
# Scores: (min: 9, avg: 73.65625, max: 500)
#
# Run: 97, exploration: 0.05, score: 258
# Scores: (min: 9, avg: 75.55670103092784, max: 500)
#
# Run: 98, exploration: 0.05, score: 56
# Scores: (min: 9, avg: 75.35714285714286, max: 500)
#
# Run: 99, exploration: 0.05, score: 86
# Scores: (min: 9, avg: 75.46464646464646, max: 500)
#
# Run: 100, exploration: 0.05, score: 70
# Scores: (min: 9, avg: 75.41, max: 500)
#
# Run: 101, exploration: 0.05, score: 33
# Scores: (min: 9, avg: 75.56, max: 500)
#
# Run: 102, exploration: 0.05, score: 17
# Scores: (min: 9, avg: 75.55, max: 500)
#
# Run: 103, exploration: 0.05, score: 18
# Scores: (min: 9, avg: 75.63, max: 500)
#
# Run: 104, exploration: 0.05, score: 44
# Scores: (min: 9, avg: 75.79, max: 500)
#
# Run: 105, exploration: 0.05, score: 14
# Scores: (min: 9, avg: 75.69, max: 500)
#
# Run: 106, exploration: 0.05, score: 50
# Scores: (min: 9, avg: 75.35, max: 500)
#
# Run: 107, exploration: 0.05, score: 36
# Scores: (min: 9, avg: 75.28, max: 500)
#
# Run: 108, exploration: 0.05, score: 43
# Scores: (min: 9, avg: 75.13, max: 500)
#
# Run: 109, exploration: 0.05, score: 79
# Scores: (min: 9, avg: 75.61, max: 500)
#
# Run: 110, exploration: 0.05, score: 109
# Scores: (min: 9, avg: 75.74, max: 500)
#
# Run: 111, exploration: 0.05, score: 142
# Scores: (min: 9, avg: 74.76, max: 500)
#
# Run: 112, exploration: 0.05, score: 127
# Scores: (min: 9, avg: 75, max: 500)
#
# Run: 113, exploration: 0.05, score: 125
# Scores: (min: 9, avg: 75.9, max: 500)
#
# Run: 114, exploration: 0.05, score: 99
# Scores: (min: 9, avg: 76.67, max: 500)
#
# Run: 115, exploration: 0.05, score: 65
# Scores: (min: 9, avg: 76.94, max: 500)
#
# Run: 116, exploration: 0.05, score: 74
# Scores: (min: 9, avg: 77.18, max: 500)
#
# Run: 117, exploration: 0.05, score: 13
# Scores: (min: 9, avg: 77.19, max: 500)
#
# Run: 118, exploration: 0.05, score: 21
# Scores: (min: 9, avg: 76.66, max: 500)
#
# Run: 119, exploration: 0.05, score: 140
# Scores: (min: 9, avg: 77.38, max: 500)
#
# Run: 120, exploration: 0.05, score: 234
# Scores: (min: 9, avg: 79.3, max: 500)
#
# Run: 121, exploration: 0.05, score: 58
# Scores: (min: 9, avg: 79.3, max: 500)
#
# Run: 122, exploration: 0.05, score: 15
# Scores: (min: 9, avg: 78.53, max: 500)
#
# Run: 123, exploration: 0.05, score: 112
# Scores: (min: 9, avg: 78.62, max: 500)
#
# Run: 124, exploration: 0.05, score: 126
# Scores: (min: 9, avg: 79.41, max: 500)
#
# Run: 125, exploration: 0.05, score: 169
# Scores: (min: 9, avg: 80.7, max: 500)
#
# Run: 126, exploration: 0.05, score: 94
# Scores: (min: 9, avg: 80.37, max: 500)
#
# Run: 127, exploration: 0.05, score: 102
# Scores: (min: 9, avg: 80.53, max: 500)
#
# Run: 128, exploration: 0.05, score: 90
# Scores: (min: 9, avg: 80.62, max: 500)
#
# Run: 129, exploration: 0.05, score: 39
# Scores: (min: 9, avg: 80.19, max: 500)
#
# Run: 130, exploration: 0.05, score: 53
# Scores: (min: 9, avg: 80.03, max: 500)
#
# Run: 131, exploration: 0.05, score: 23
# Scores: (min: 9, avg: 78.99, max: 500)
#
# Run: 132, exploration: 0.05, score: 325
# Scores: (min: 9, avg: 82.14, max: 500)
#
# Run: 133, exploration: 0.05, score: 17
# Scores: (min: 9, avg: 82.22, max: 500)
#
# Run: 134, exploration: 0.05, score: 17
# Scores: (min: 9, avg: 82.26, max: 500)
#
# Run: 135, exploration: 0.05, score: 69
# Scores: (min: 9, avg: 82.85, max: 500)
#
# Run: 136, exploration: 0.05, score: 92
# Scores: (min: 9, avg: 83.66, max: 500)
#
# Run: 137, exploration: 0.05, score: 89
# Scores: (min: 9, avg: 83.64, max: 500)
#
# Run: 138, exploration: 0.05, score: 11
# Scores: (min: 9, avg: 82.9, max: 500)
#
# Run: 139, exploration: 0.05, score: 167
# Scores: (min: 9, avg: 84.42, max: 500)
#
# Run: 140, exploration: 0.05, score: 19
# Scores: (min: 9, avg: 84.38, max: 500)
#
# Run: 141, exploration: 0.05, score: 117
# Scores: (min: 9, avg: 84.05, max: 500)
#
# Run: 142, exploration: 0.05, score: 87
# Scores: (min: 10, avg: 84.83, max: 500)
#
# Run: 143, exploration: 0.05, score: 89
# Scores: (min: 10, avg: 84.93, max: 500)
#
# Run: 144, exploration: 0.05, score: 129
# Scores: (min: 10, avg: 85.8, max: 500)
#
# Run: 145, exploration: 0.05, score: 97
# Scores: (min: 10, avg: 86.65, max: 500)
#
# Run: 146, exploration: 0.05, score: 116
# Scores: (min: 10, avg: 86.42, max: 500)
#
# Run: 147, exploration: 0.05, score: 34
# Scores: (min: 10, avg: 86.49, max: 500)
#
# Run: 148, exploration: 0.05, score: 97
# Scores: (min: 10, avg: 87.09, max: 500)
#
# Run: 149, exploration: 0.05, score: 19
# Scores: (min: 10, avg: 86.59, max: 500)
#
# Run: 150, exploration: 0.05, score: 33
# Scores: (min: 10, avg: 85.33, max: 500)
#
# Run: 151, exploration: 0.05, score: 26
# Scores: (min: 10, avg: 85.48, max: 500)
#
# Run: 152, exploration: 0.05, score: 21
# Scores: (min: 10, avg: 84.35, max: 500)
#
# Run: 153, exploration: 0.05, score: 58
# Scores: (min: 10, avg: 79.93, max: 325)
#
# Run: 154, exploration: 0.05, score: 94
# Scores: (min: 10, avg: 79.42, max: 325)
#
# Run: 155, exploration: 0.05, score: 22
# Scores: (min: 10, avg: 78.99, max: 325)
#
# Run: 156, exploration: 0.05, score: 56
# Scores: (min: 10, avg: 78.36, max: 325)
#
# Run: 157, exploration: 0.05, score: 30
# Scores: (min: 10, avg: 77.44, max: 325)
#
# Run: 158, exploration: 0.05, score: 33
# Scores: (min: 10, avg: 76.4, max: 325)
#
# Run: 159, exploration: 0.05, score: 168
# Scores: (min: 10, avg: 77.72, max: 325)
#
# Run: 160, exploration: 0.05, score: 164
# Scores: (min: 10, avg: 79.18, max: 325)
#
# Run: 161, exploration: 0.05, score: 24
# Scores: (min: 10, avg: 79.3, max: 325)
#
# Run: 162, exploration: 0.05, score: 131
# Scores: (min: 10, avg: 80.49, max: 325)
#
# Run: 163, exploration: 0.05, score: 228
# Scores: (min: 10, avg: 82.39, max: 325)
#
# Run: 164, exploration: 0.05, score: 116
# Scores: (min: 10, avg: 83.19, max: 325)
#
# Run: 165, exploration: 0.05, score: 15
# Scores: (min: 10, avg: 82.29, max: 325)
#
# Run: 166, exploration: 0.05, score: 42
# Scores: (min: 10, avg: 81.18, max: 325)
#
# Run: 167, exploration: 0.05, score: 123
# Scores: (min: 10, avg: 81.45, max: 325)
#
# Run: 168, exploration: 0.05, score: 105
# Scores: (min: 11, avg: 82.4, max: 325)
#
# Run: 169, exploration: 0.05, score: 97
# Scores: (min: 11, avg: 82.76, max: 325)
#
# Run: 170, exploration: 0.05, score: 64
# Scores: (min: 11, avg: 82.77, max: 325)
#
# Run: 171, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 81.96, max: 325)
#
# Run: 172, exploration: 0.05, score: 56
# Scores: (min: 11, avg: 81.75, max: 325)
#
# Run: 173, exploration: 0.05, score: 40
# Scores: (min: 11, avg: 80.32, max: 325)
#
# Run: 174, exploration: 0.05, score: 35
# Scores: (min: 11, avg: 79.43, max: 325)
#
# Run: 175, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 78.73, max: 325)
#
# Run: 176, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 78.78, max: 325)
#
# Run: 177, exploration: 0.05, score: 153
# Scores: (min: 11, avg: 79.42, max: 325)
#
# Run: 178, exploration: 0.05, score: 36
# Scores: (min: 11, avg: 78.94, max: 325)
#
# Run: 179, exploration: 0.05, score: 76
# Scores: (min: 11, avg: 78.95, max: 325)
#
# Run: 180, exploration: 0.05, score: 254
# Scores: (min: 11, avg: 80.45, max: 325)
#
# Run: 181, exploration: 0.05, score: 130
# Scores: (min: 11, avg: 80.77, max: 325)
#
# Run: 182, exploration: 0.05, score: 165
# Scores: (min: 11, avg: 81.77, max: 325)
#
# Run: 183, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 80.85, max: 325)
#
# Run: 184, exploration: 0.05, score: 233
# Scores: (min: 11, avg: 81.79, max: 325)
#
# Run: 185, exploration: 0.05, score: 75
# Scores: (min: 11, avg: 80.06, max: 325)
#
# Run: 186, exploration: 0.05, score: 58
# Scores: (min: 11, avg: 80.13, max: 325)
#
# Run: 187, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 81.01, max: 325)
#
# Run: 188, exploration: 0.05, score: 54
# Scores: (min: 11, avg: 81.41, max: 325)
#
# Run: 189, exploration: 0.05, score: 20
# Scores: (min: 11, avg: 80.63, max: 325)
#
# Run: 190, exploration: 0.05, score: 87
# Scores: (min: 11, avg: 80.84, max: 325)
#
# Run: 191, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 80.57, max: 325)
#
# Run: 192, exploration: 0.05, score: 38
# Scores: (min: 11, avg: 80.74, max: 325)
#
# Run: 193, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 80.7, max: 325)
#
# Run: 194, exploration: 0.05, score: 144
# Scores: (min: 11, avg: 81.58, max: 325)
#
# Run: 195, exploration: 0.05, score: 72
# Scores: (min: 11, avg: 81.87, max: 325)
#
# Run: 196, exploration: 0.05, score: 34
# Scores: (min: 11, avg: 82.06, max: 325)
# Run: 197, exploration: 0.05, score: 71
# Scores: (min: 11, avg: 80.19, max: 325)
#
# Run: 198, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 80.58, max: 325)
#
# Run: 199, exploration: 0.05, score: 148
# Scores: (min: 11, avg: 81.2, max: 325)
#
# Run: 200, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 80.77, max: 325)
#
# Run: 201, exploration: 0.05, score: 109
# Scores: (min: 11, avg: 81.53, max: 325)
#
# Run: 202, exploration: 0.05, score: 69
# Scores: (min: 11, avg: 82.05, max: 325)
#
# Run: 203, exploration: 0.05, score: 78
# Scores: (min: 11, avg: 82.65, max: 325)
#
# Run: 204, exploration: 0.05, score: 18
# Scores: (min: 11, avg: 82.39, max: 325)
#
# Run: 205, exploration: 0.05, score: 100
# Scores: (min: 11, avg: 83.25, max: 325)
#
# Run: 206, exploration: 0.05, score: 34
# Scores: (min: 11, avg: 83.09, max: 325)
#
# Run: 207, exploration: 0.05, score: 45
# Scores: (min: 11, avg: 83.18, max: 325)
#
# Run: 208, exploration: 0.05, score: 110
# Scores: (min: 11, avg: 83.85, max: 325)
#
# Run: 209, exploration: 0.05, score: 164
# Scores: (min: 11, avg: 84.7, max: 325)
#
# Run: 210, exploration: 0.05, score: 119
# Scores: (min: 11, avg: 84.8, max: 325)
#
# Run: 211, exploration: 0.05, score: 121
# Scores: (min: 11, avg: 84.59, max: 325)
#
# Run: 212, exploration: 0.05, score: 34
# Scores: (min: 11, avg: 83.66, max: 325)
#
# Run: 213, exploration: 0.05, score: 137
# Scores: (min: 11, avg: 83.78, max: 325)
#
# Run: 214, exploration: 0.05, score: 87
# Scores: (min: 11, avg: 83.66, max: 325)
#
# Run: 215, exploration: 0.05, score: 69
# Scores: (min: 11, avg: 83.7, max: 325)
#
# Run: 216, exploration: 0.05, score: 46
# Scores: (min: 11, avg: 83.42, max: 325)
#
# Run: 217, exploration: 0.05, score: 36
# Scores: (min: 11, avg: 83.65, max: 325)
#
# Run: 218, exploration: 0.05, score: 104
# Scores: (min: 11, avg: 84.48, max: 325)
#
# Run: 219, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 84.1, max: 325)
#
# Run: 220, exploration: 0.05, score: 254
# Scores: (min: 11, avg: 84.3, max: 325)
#
# Run: 221, exploration: 0.05, score: 54
# Scores: (min: 11, avg: 84.26, max: 325)
#
# Run: 222, exploration: 0.05, score: 181
# Scores: (min: 11, avg: 85.92, max: 325)
#
# Run: 223, exploration: 0.05, score: 46
# Scores: (min: 11, avg: 85.26, max: 325)
#
# Run: 224, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 84.43, max: 325)
#
# Run: 225, exploration: 0.05, score: 115
# Scores: (min: 11, avg: 83.89, max: 325)
#
# Run: 226, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 84.03, max: 325)
#
# Run: 227, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 83.91, max: 325)
#
# Run: 228, exploration: 0.05, score: 51
# Scores: (min: 11, avg: 83.52, max: 325)
#
# Run: 229, exploration: 0.05, score: 232
# Scores: (min: 11, avg: 85.45, max: 325)
#
# Run: 230, exploration: 0.05, score: 124
# Scores: (min: 11, avg: 86.16, max: 325)
#
# Run: 231, exploration: 0.05, score: 325
# Scores: (min: 11, avg: 89.18, max: 325)
#
# Run: 232, exploration: 0.05, score: 177
# Scores: (min: 11, avg: 87.7, max: 325)
#
# Run: 233, exploration: 0.05, score: 75
# Scores: (min: 11, avg: 88.28, max: 325)
#
# Run: 234, exploration: 0.05, score: 155
# Scores: (min: 11, avg: 89.66, max: 325)
#
# Run: 235, exploration: 0.05, score: 20
# Scores: (min: 11, avg: 89.17, max: 325)
#
# Run: 236, exploration: 0.05, score: 173
# Scores: (min: 11, avg: 89.98, max: 325)
#
# Run: 237, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 89.36, max: 325)
#
# Run: 238, exploration: 0.05, score: 30
# Scores: (min: 11, avg: 89.55, max: 325)
#
# Run: 239, exploration: 0.05, score: 51
# Scores: (min: 11, avg: 88.39, max: 325)
#
# Run: 240, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 89.28, max: 325)
#
# Run: 241, exploration: 0.05, score: 112
# Scores: (min: 11, avg: 89.23, max: 325)
#
# Run: 242, exploration: 0.05, score: 15
# Scores: (min: 11, avg: 88.51, max: 325)
#
# Run: 243, exploration: 0.05, score: 33
# Scores: (min: 11, avg: 87.95, max: 325)
#
# Run: 244, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 86.78, max: 325)
#
# Run: 245, exploration: 0.05, score: 37
# Scores: (min: 11, avg: 86.18, max: 325)
#
# Run: 246, exploration: 0.05, score: 22
# Scores: (min: 11, avg: 85.24, max: 325)
#
# Run: 247, exploration: 0.05, score: 15
# Scores: (min: 11, avg: 85.05, max: 325)
#
# Run: 248, exploration: 0.05, score: 33
# Scores: (min: 11, avg: 84.41, max: 325)
#
# Run: 249, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 85.06, max: 325)
#
# Run: 250, exploration: 0.05, score: 61
# Scores: (min: 11, avg: 85.34, max: 325)
#
# Run: 251, exploration: 0.05, score: 144
# Scores: (min: 11, avg: 86.52, max: 325)
#
# Run: 252, exploration: 0.05, score: 71
# Scores: (min: 11, avg: 87.02, max: 325)
#
# Run: 253, exploration: 0.05, score: 41
# Scores: (min: 11, avg: 86.85, max: 325)
#
# Run: 254, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 86.03, max: 325)
#
# Run: 255, exploration: 0.05, score: 28
# Scores: (min: 11, avg: 86.09, max: 325)
#
# Run: 256, exploration: 0.05, score: 28
# Scores: (min: 11, avg: 85.81, max: 325)
#
# Run: 257, exploration: 0.05, score: 72
# Scores: (min: 11, avg: 86.23, max: 325)
#
# Run: 258, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 87.15, max: 325)
#
# Run: 259, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 85.61, max: 325)
#
# Run: 260, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 84.96, max: 325)
#
# Run: 261, exploration: 0.05, score: 101
# Scores: (min: 11, avg: 85.73, max: 325)
#
# Run: 262, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 84.71, max: 325)
#
# Run: 263, exploration: 0.05, score: 41
# Scores: (min: 11, avg: 82.84, max: 325)
#
# Run: 264, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 82.71, max: 325)
#
# Run: 265, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 82.81, max: 325)
#
# Run: 266, exploration: 0.05, score: 105
# Scores: (min: 11, avg: 83.44, max: 325)
#
# Run: 267, exploration: 0.05, score: 97
# Scores: (min: 11, avg: 83.18, max: 325)
#
# Run: 268, exploration: 0.05, score: 44
# Scores: (min: 11, avg: 82.57, max: 325)
#
# Run: 269, exploration: 0.05, score: 19
# Scores: (min: 11, avg: 81.79, max: 325)
#
# Run: 270, exploration: 0.05, score: 80
# Scores: (min: 11, avg: 81.95, max: 325)
#
# Run: 271, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 81.93, max: 325)
#
# Run: 272, exploration: 0.05, score: 66
# Scores: (min: 11, avg: 82.03, max: 325)
#
# Run: 273, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 81.79, max: 325)
#
# Run: 274, exploration: 0.05, score: 38
# Scores: (min: 11, avg: 81.82, max: 325)
#
# Run: 275, exploration: 0.05, score: 47
# Scores: (min: 11, avg: 82.13, max: 325)
#
# Run: 276, exploration: 0.05, score: 57
# Scores: (min: 11, avg: 81.67, max: 325)
#
# Run: 277, exploration: 0.05, score: 70
# Scores: (min: 11, avg: 80.84, max: 325)
#
# Run: 278, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 81.38, max: 325)
#
# Run: 279, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 81.52, max: 325)
#
# Run: 280, exploration: 0.05, score: 61
# Scores: (min: 11, avg: 79.59, max: 325)
#
# Run: 281, exploration: 0.05, score: 18
# Scores: (min: 11, avg: 78.47, max: 325)
#
# Run: 282, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 76.96, max: 325)
#
# Run: 283, exploration: 0.05, score: 71
# Scores: (min: 12, avg: 77.56, max: 325)
#
# Run: 284, exploration: 0.05, score: 16
# Scores: (min: 12, avg: 75.39, max: 325)
#
# Run: 285, exploration: 0.05, score: 29
# Scores: (min: 12, avg: 74.93, max: 325)
#
# Run: 286, exploration: 0.05, score: 61
# Scores: (min: 12, avg: 74.96, max: 325)
#
# Run: 287, exploration: 0.05, score: 36
# Scores: (min: 12, avg: 74.24, max: 325)
#
# Run: 288, exploration: 0.05, score: 100
# Scores: (min: 12, avg: 74.7, max: 325)
#
# Run: 289, exploration: 0.05, score: 73
# Scores: (min: 12, avg: 75.23, max: 325)
#
# Run: 290, exploration: 0.05, score: 92
# Scores: (min: 12, avg: 75.28, max: 325)
#
# Run: 291, exploration: 0.05, score: 40
# Scores: (min: 12, avg: 74.65, max: 325)
#
# Run: 292, exploration: 0.05, score: 209
# Scores: (min: 12, avg: 76.36, max: 325)
#
# Run: 293, exploration: 0.05, score: 49
# Scores: (min: 12, avg: 76.71, max: 325)
#
# Run: 294, exploration: 0.05, score: 120
# Scores: (min: 12, avg: 76.47, max: 325)
#
# Run: 295, exploration: 0.05, score: 53
# Scores: (min: 12, avg: 76.28, max: 325)
#
# Run: 296, exploration: 0.05, score: 232
# Scores: (min: 12, avg: 78.26, max: 325)
#
# Run: 297, exploration: 0.05, score: 22
# Scores: (min: 12, avg: 77.77, max: 325)
#
# Run: 298, exploration: 0.05, score: 105
# Scores: (min: 12, avg: 77.87, max: 325)
#
# Run: 299, exploration: 0.05, score: 93
# Scores: (min: 12, avg: 77.32, max: 325)
# Run: 300, exploration: 0.05, score: 56
# Scores: (min: 12, avg: 77.61, max: 325)
#
# Run: 301, exploration: 0.05, score: 89
# Scores: (min: 12, avg: 77.41, max: 325)
#
# Run: 302, exploration: 0.05, score: 49
# Scores: (min: 12, avg: 77.21, max: 325)
#
# Run: 303, exploration: 0.05, score: 301
# Scores: (min: 12, avg: 79.44, max: 325)
#
# Run: 304, exploration: 0.05, score: 15
# Scores: (min: 12, avg: 79.41, max: 325)
#
# Run: 305, exploration: 0.05, score: 101
# Scores: (min: 12, avg: 79.42, max: 325)
#
# Run: 306, exploration: 0.05, score: 90
# Scores: (min: 12, avg: 79.98, max: 325)
#
# Run: 307, exploration: 0.05, score: 14
# Scores: (min: 12, avg: 79.67, max: 325)
#
# Run: 308, exploration: 0.05, score: 45
# Scores: (min: 12, avg: 79.02, max: 325)
#
# Run: 309, exploration: 0.05, score: 71
# Scores: (min: 12, avg: 78.09, max: 325)
#
# Run: 310, exploration: 0.05, score: 20
# Scores: (min: 12, avg: 77.1, max: 325)
#
# Run: 311, exploration: 0.05, score: 96
# Scores: (min: 12, avg: 76.85, max: 325)
#
# Run: 312, exploration: 0.05, score: 75
# Scores: (min: 12, avg: 77.26, max: 325)
#
# Run: 313, exploration: 0.05, score: 97
# Scores: (min: 12, avg: 76.86, max: 325)
#
# Run: 314, exploration: 0.05, score: 93
# Scores: (min: 12, avg: 76.92, max: 325)
#
# Run: 315, exploration: 0.05, score: 161
# Scores: (min: 12, avg: 77.84, max: 325)
#
# Run: 316, exploration: 0.05, score: 223
# Scores: (min: 12, avg: 79.61, max: 325)
#
# Run: 317, exploration: 0.05, score: 16
# Scores: (min: 12, avg: 79.41, max: 325)
#
# Run: 318, exploration: 0.05, score: 109
# Scores: (min: 12, avg: 79.46, max: 325)
#
# Run: 319, exploration: 0.05, score: 18
# Scores: (min: 12, avg: 78.62, max: 325)
#
# Run: 320, exploration: 0.05, score: 77
# Scores: (min: 12, avg: 76.85, max: 325)
#
# Run: 321, exploration: 0.05, score: 95
# Scores: (min: 12, avg: 77.26, max: 325)
#
# Run: 322, exploration: 0.05, score: 27
# Scores: (min: 12, avg: 75.72, max: 325)
#
# Run: 323, exploration: 0.05, score: 122
# Scores: (min: 12, avg: 76.48, max: 325)
#
# Run: 324, exploration: 0.05, score: 91
# Scores: (min: 12, avg: 76.96, max: 325)
#
# Run: 325, exploration: 0.05, score: 24
# Scores: (min: 12, avg: 76.05, max: 325)
#
# Run: 326, exploration: 0.05, score: 104
# Scores: (min: 12, avg: 76.01, max: 325)
#
# Run: 327, exploration: 0.05, score: 14
# Scores: (min: 12, avg: 75.25, max: 325)
#
# Run: 328, exploration: 0.05, score: 68
# Scores: (min: 12, avg: 75.42, max: 325)
#
# Run: 329, exploration: 0.05, score: 28
# Scores: (min: 12, avg: 73.38, max: 325)
#
# Run: 330, exploration: 0.05, score: 16
# Scores: (min: 12, avg: 72.3, max: 325)
#
# Run: 331, exploration: 0.05, score: 151
# Scores: (min: 12, avg: 70.56, max: 301)
#
# Run: 332, exploration: 0.05, score: 179
# Scores: (min: 12, avg: 70.58, max: 301)
#
# Run: 333, exploration: 0.05, score: 96
# Scores: (min: 12, avg: 70.79, max: 301)
#
# Run: 334, exploration: 0.05, score: 163
# Scores: (min: 12, avg: 70.87, max: 301)
#
# Run: 335, exploration: 0.05, score: 33
# Scores: (min: 12, avg: 71, max: 301)
#
# Run: 336, exploration: 0.05, score: 307
# Scores: (min: 12, avg: 72.34, max: 307)
#
# Run: 337, exploration: 0.05, score: 36
# Scores: (min: 12, avg: 72.43, max: 307)
#
# Run: 338, exploration: 0.05, score: 17
# Scores: (min: 12, avg: 72.3, max: 307)
#
# Run: 339, exploration: 0.05, score: 253
# Scores: (min: 12, avg: 74.32, max: 307)
#
# Run: 340, exploration: 0.05, score: 38
# Scores: (min: 12, avg: 73.62, max: 307)
#
# Run: 341, exploration: 0.05, score: 25
# Scores: (min: 12, avg: 72.75, max: 307)
#
# Run: 342, exploration: 0.05, score: 35
# Scores: (min: 12, avg: 72.95, max: 307)
#
# Run: 343, exploration: 0.05, score: 71
# Scores: (min: 12, avg: 73.33, max: 307)
#
# Run: 344, exploration: 0.05, score: 43
# Scores: (min: 12, avg: 73.64, max: 307)
#
# Run: 345, exploration: 0.05, score: 34
# Scores: (min: 12, avg: 73.61, max: 307)
#
# Run: 346, exploration: 0.05, score: 57
# Scores: (min: 12, avg: 73.96, max: 307)
#
# Run: 347, exploration: 0.05, score: 55
# Scores: (min: 12, avg: 74.36, max: 307)
#
# Run: 348, exploration: 0.05, score: 52
# Scores: (min: 12, avg: 74.55, max: 307)
#
# Run: 349, exploration: 0.05, score: 114
# Scores: (min: 12, avg: 74.85, max: 307)
#
# Run: 350, exploration: 0.05, score: 68
# Scores: (min: 12, avg: 74.92, max: 307)
#
# Run: 351, exploration: 0.05, score: 25
# Scores: (min: 12, avg: 73.73, max: 307)
#
# Run: 352, exploration: 0.05, score: 108
# Scores: (min: 12, avg: 74.1, max: 307)
#
# Run: 353, exploration: 0.05, score: 70
# Scores: (min: 12, avg: 74.39, max: 307)
#
# Run: 354, exploration: 0.05, score: 101
# Scores: (min: 14, avg: 75.28, max: 307)
#
# Run: 355, exploration: 0.05, score: 74
# Scores: (min: 14, avg: 75.74, max: 307)
#
# Run: 356, exploration: 0.05, score: 80
# Scores: (min: 14, avg: 76.26, max: 307)
#
# Run: 357, exploration: 0.05, score: 102
# Scores: (min: 14, avg: 76.56, max: 307)
#
# Run: 358, exploration: 0.05, score: 124
# Scores: (min: 14, avg: 76.55, max: 307)
#
# Run: 359, exploration: 0.05, score: 102
# Scores: (min: 14, avg: 77.43, max: 307)
#
# Run: 360, exploration: 0.05, score: 87
# Scores: (min: 14, avg: 77.31, max: 307)
#
# Run: 361, exploration: 0.05, score: 99
# Scores: (min: 14, avg: 77.29, max: 307)
#
# Run: 362, exploration: 0.05, score: 134
# Scores: (min: 14, avg: 78.34, max: 307)
#
# Run: 363, exploration: 0.05, score: 49
# Scores: (min: 14, avg: 78.42, max: 307)
#
# Run: 364, exploration: 0.05, score: 109
# Scores: (min: 14, avg: 78.48, max: 307)
#
# Run: 365, exploration: 0.05, score: 118
# Scores: (min: 14, avg: 79.41, max: 307)
#
# Run: 366, exploration: 0.05, score: 104
# Scores: (min: 14, avg: 79.4, max: 307)
#
# Run: 367, exploration: 0.05, score: 29
# Scores: (min: 14, avg: 78.72, max: 307)
#
# Run: 368, exploration: 0.05, score: 47
# Scores: (min: 14, avg: 78.75, max: 307)
#
# Run: 369, exploration: 0.05, score: 52
# Scores: (min: 14, avg: 79.08, max: 307)
#
# Run: 370, exploration: 0.05, score: 17
# Scores: (min: 14, avg: 78.45, max: 307)
#
# Run: 371, exploration: 0.05, score: 58
# Scores: (min: 14, avg: 78.89, max: 307)
#
# Run: 372, exploration: 0.05, score: 106
# Scores: (min: 14, avg: 79.29, max: 307)
#
# Run: 373, exploration: 0.05, score: 222
# Scores: (min: 14, avg: 81.35, max: 307)
#
# Run: 374, exploration: 0.05, score: 21
# Scores: (min: 14, avg: 81.18, max: 307)
#
# Run: 375, exploration: 0.05, score: 124
# Scores: (min: 14, avg: 81.95, max: 307)
#
# Run: 376, exploration: 0.05, score: 42
# Scores: (min: 14, avg: 81.8, max: 307)
#
# Run: 377, exploration: 0.05, score: 140
# Scores: (min: 14, avg: 82.5, max: 307)
#
# Run: 378, exploration: 0.05, score: 14
# Scores: (min: 14, avg: 81.74, max: 307)
#
# Run: 379, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 80.95, max: 307)
#
# Run: 380, exploration: 0.05, score: 89
# Scores: (min: 11, avg: 81.23, max: 307)
#
# Run: 381, exploration: 0.05, score: 78
# Scores: (min: 11, avg: 81.83, max: 307)
#
# Run: 382, exploration: 0.05, score: 119
# Scores: (min: 11, avg: 82.88, max: 307)
#
# Run: 383, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 83.19, max: 307)
#
# Run: 384, exploration: 0.05, score: 26
# Scores: (min: 11, avg: 83.29, max: 307)
#
# Run: 385, exploration: 0.05, score: 166
# Scores: (min: 11, avg: 84.66, max: 307)
#
# Run: 386, exploration: 0.05, score: 118
# Scores: (min: 11, avg: 85.23, max: 307)
#
# Run: 387, exploration: 0.05, score: 61
# Scores: (min: 11, avg: 85.48, max: 307)
#
# Run: 388, exploration: 0.05, score: 151
# Scores: (min: 11, avg: 85.99, max: 307)
#
# Run: 389, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 86.28, max: 307)
#
# Run: 390, exploration: 0.05, score: 52
# Scores: (min: 11, avg: 85.88, max: 307)
#
# Run: 391, exploration: 0.05, score: 123
# Scores: (min: 11, avg: 86.71, max: 307)
#
# Run: 392, exploration: 0.05, score: 159
# Scores: (min: 11, avg: 86.21, max: 307)
#
# Run: 393, exploration: 0.05, score: 122
# Scores: (min: 11, avg: 86.94, max: 307)
#
# Run: 394, exploration: 0.05, score: 193
# Scores: (min: 11, avg: 87.67, max: 307)
#
# Run: 395, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 88.08, max: 307)
#
# Run: 396, exploration: 0.05, score: 58
# Scores: (min: 11, avg: 86.34, max: 307)
#
# Run: 397, exploration: 0.05, score: 171
# Scores: (min: 11, avg: 87.83, max: 307)
#
# Run: 398, exploration: 0.05, score: 135
# Scores: (min: 11, avg: 88.13, max: 307)
#
# Run: 399, exploration: 0.05, score: 60
# Scores: (min: 11, avg: 87.8, max: 307)
#
# Run: 400, exploration: 0.05, score: 21
# Scores: (min: 11, avg: 87.45, max: 307)
#
# Run: 401, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 86.85, max: 307)
#
# Run: 402, exploration: 0.05, score: 44
# Scores: (min: 11, avg: 86.8, max: 307)
# Run: 403, exploration: 0.05, score: 55
# Scores: (min: 11, avg: 84.34, max: 307)
#
# Run: 404, exploration: 0.05, score: 36
# Scores: (min: 11, avg: 84.55, max: 307)
#
# Run: 405, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 83.79, max: 307)
#
# Run: 406, exploration: 0.05, score: 91
# Scores: (min: 11, avg: 83.8, max: 307)
#
# Run: 407, exploration: 0.05, score: 19
# Scores: (min: 11, avg: 83.85, max: 307)
#
# Run: 408, exploration: 0.05, score: 104
# Scores: (min: 11, avg: 84.44, max: 307)
#
# Run: 409, exploration: 0.05, score: 70
# Scores: (min: 11, avg: 84.43, max: 307)
#
# Run: 410, exploration: 0.05, score: 17
# Scores: (min: 11, avg: 84.4, max: 307)
#
# Run: 411, exploration: 0.05, score: 15
# Scores: (min: 11, avg: 83.59, max: 307)
#
# Run: 412, exploration: 0.05, score: 81
# Scores: (min: 11, avg: 83.65, max: 307)
#
# Run: 413, exploration: 0.05, score: 10
# Scores: (min: 10, avg: 82.78, max: 307)
#
# Run: 414, exploration: 0.05, score: 35
# Scores: (min: 10, avg: 82.2, max: 307)
#
# Run: 415, exploration: 0.05, score: 20
# Scores: (min: 10, avg: 80.79, max: 307)
#
# Run: 416, exploration: 0.05, score: 118
# Scores: (min: 10, avg: 79.74, max: 307)
#
# Run: 417, exploration: 0.05, score: 88
# Scores: (min: 10, avg: 80.46, max: 307)
#
# Run: 418, exploration: 0.05, score: 30
# Scores: (min: 10, avg: 79.67, max: 307)
#
# Run: 419, exploration: 0.05, score: 17
# Scores: (min: 10, avg: 79.66, max: 307)
#
# Run: 420, exploration: 0.05, score: 99
# Scores: (min: 10, avg: 79.88, max: 307)
#
# Run: 421, exploration: 0.05, score: 44
# Scores: (min: 10, avg: 79.37, max: 307)
#
# Run: 422, exploration: 0.05, score: 188
# Scores: (min: 10, avg: 80.98, max: 307)
#
# Run: 423, exploration: 0.05, score: 52
# Scores: (min: 10, avg: 80.28, max: 307)
#
# Run: 424, exploration: 0.05, score: 119
# Scores: (min: 10, avg: 80.56, max: 307)
#
# Run: 425, exploration: 0.05, score: 75
# Scores: (min: 10, avg: 81.07, max: 307)
#
# Run: 426, exploration: 0.05, score: 11
# Scores: (min: 10, avg: 80.14, max: 307)
#
# Run: 427, exploration: 0.05, score: 9
# Scores: (min: 9, avg: 80.09, max: 307)
#
# Run: 428, exploration: 0.05, score: 10
# Scores: (min: 9, avg: 79.51, max: 307)
#
# Run: 429, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 79.31, max: 307)
#
# Run: 430, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 79.24, max: 307)
#
# Run: 431, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 77.83, max: 307)
#
# Run: 432, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 76.14, max: 307)
#
# Run: 433, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 75.27, max: 307)
#
# Run: 434, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 73.74, max: 307)
#
# Run: 435, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 73.5, max: 307)
#
# Run: 436, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 70.51, max: 253)
#
# Run: 437, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 70.28, max: 253)
#
# Run: 438, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 70.21, max: 253)
#
# Run: 439, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 67.76, max: 222)
#
# Run: 440, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 67.48, max: 222)
#
# Run: 441, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 67.32, max: 222)
#
# Run: 442, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 67.06, max: 222)
#
# Run: 443, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 66.45, max: 222)
#
# Run: 444, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 66.12, max: 222)
#
# Run: 445, exploration: 0.05, score: 74
# Scores: (min: 8, avg: 66.52, max: 222)
#
# Run: 446, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 66.04, max: 222)
#
# Run: 447, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 65.58, max: 222)
#
# Run: 448, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 65.15, max: 222)
#
# Run: 449, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 64.1, max: 222)
#
# Run: 450, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 63.52, max: 222)
#
# Run: 451, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 63.37, max: 222)
#
# Run: 452, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 62.39, max: 222)
#
# Run: 453, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 61.77, max: 222)
#
# Run: 454, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 60.85, max: 222)
#
# Run: 455, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 60.2, max: 222)
#
# Run: 456, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 59.52, max: 222)
#
# Run: 457, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 58.59, max: 222)
#
# Run: 458, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 57.44, max: 222)
#
# Run: 459, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 56.51, max: 222)
#
# Run: 460, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 55.74, max: 222)
#
# Run: 461, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 54.83, max: 222)
#
# Run: 462, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 53.57, max: 222)
#
# Run: 463, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 53.19, max: 222)
#
# Run: 464, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 52.18, max: 222)
#
# Run: 465, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 51.09, max: 222)
#
# Run: 466, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 50.14, max: 222)
#
# Run: 467, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 49.94, max: 222)
#
# Run: 468, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 49.57, max: 222)
#
# Run: 469, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 49.14, max: 222)
#
# Run: 470, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 49.06, max: 222)
#
# Run: 471, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 48.59, max: 222)
#
# Run: 472, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 47.61, max: 222)
#
# Run: 473, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 45.49, max: 193)
#
# Run: 474, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 45.37, max: 193)
#
# Run: 475, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 44.24, max: 193)
#
# Run: 476, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 43.91, max: 193)
#
# Run: 477, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 42.61, max: 193)
#
# Run: 478, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 42.58, max: 193)
#
# Run: 479, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 42.57, max: 193)
#
# Run: 480, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 41.77, max: 193)
#
# Run: 481, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 41.08, max: 193)
#
# Run: 482, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 40, max: 193)
#
# Run: 483, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 39.08, max: 193)
#
# Run: 484, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 38.92, max: 193)
#
# Run: 485, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 37.36, max: 193)
#
# Run: 486, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 36.28, max: 193)
#
# Run: 487, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 35.76, max: 193)
#
# Run: 488, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 34.36, max: 193)
#
# Run: 489, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 33.44, max: 193)
#
# Run: 490, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 33.06, max: 193)
#
# Run: 491, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 31.93, max: 193)
#
# Run: 492, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 30.43, max: 193)
#
# Run: 493, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 29.31, max: 193)
#
# Run: 494, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 27.49, max: 188)
#
# Run: 495, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 26.64, max: 188)
#
# Run: 496, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 26.15, max: 188)
#
# Run: 497, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 24.55, max: 188)
#
# Run: 498, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 23.3, max: 188)
#
# Run: 499, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 22.79, max: 188)
#
# Run: 500, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 22.67, max: 188)
#
# Run: 501, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 22.47, max: 188)
#
# Run: 502, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 22.11, max: 188)
#
# Run: 503, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 21.67, max: 188)
#
# Run: 504, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 21.4, max: 188)
#
# Run: 505, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 21.24, max: 188)
#
# Run: 506, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 20.43, max: 188)
#
# Run: 507, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 20.34, max: 188)
# Run: 508, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 19.39, max: 188)
#
# Run: 509, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.79, max: 188)
#
# Run: 510, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 18.72, max: 188)
#
# Run: 511, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 18.66, max: 188)
#
# Run: 512, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 17.94, max: 188)
#
# Run: 513, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 17.92, max: 188)
#
# Run: 514, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 17.67, max: 188)
#
# Run: 515, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 17.58, max: 188)
#
# Run: 516, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 16.49, max: 188)
#
# Run: 517, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 15.72, max: 188)
#
# Run: 518, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 15.5, max: 188)
#
# Run: 519, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 15.43, max: 188)
#
# Run: 520, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 14.52, max: 188)
#
# Run: 521, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.18, max: 188)
#
# Run: 522, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 12.4, max: 119)
#
# Run: 523, exploration: 0.05, score: 8
# Scores: (min: 8, avg: 11.96, max: 119)
#
# Run: 524, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 10.86, max: 75)
#
# Run: 525, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 10.21, max: 74)
#
# Run: 526, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 10.2, max: 74)
#
# Run: 527, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 10.21, max: 74)
#
# Run: 528, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 10.21, max: 74)
#
# Run: 529, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 10.23, max: 74)
#
# Run: 530, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 10.23, max: 74)
#
# Run: 531, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 10.24, max: 74)
#
# Run: 532, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 10.26, max: 74)
#
# Run: 533, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 10.28, max: 74)
#
# Run: 534, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 10.33, max: 74)
#
# Run: 535, exploration: 0.05, score: 96
# Scores: (min: 8, avg: 11.2, max: 96)
#
# Run: 536, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 11.33, max: 96)
#
# Run: 537, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 11.31, max: 96)
#
# Run: 538, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 11.42, max: 96)
#
# Run: 539, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 11.45, max: 96)
#
# Run: 540, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 11.57, max: 96)
#
# Run: 541, exploration: 0.05, score: 41
# Scores: (min: 8, avg: 11.89, max: 96)
#
# Run: 542, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 11.9, max: 96)
#
# Run: 543, exploration: 0.05, score: 30
# Scores: (min: 8, avg: 12.1, max: 96)
#
# Run: 544, exploration: 0.05, score: 11
# Scores: (min: 8, avg: 12.11, max: 96)
#
# Run: 545, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 11.58, max: 96)
#
# Run: 546, exploration: 0.05, score: 16
# Scores: (min: 8, avg: 11.65, max: 96)
#
# Run: 547, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 11.71, max: 96)
#
# Run: 548, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 11.77, max: 96)
#
# Run: 549, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 11.78, max: 96)
#
# Run: 550, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 11.82, max: 96)
#
# Run: 551, exploration: 0.05, score: 28
# Scores: (min: 8, avg: 12, max: 96)
#
# Run: 552, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 12.14, max: 96)
#
# Run: 553, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 12.19, max: 96)
#
# Run: 554, exploration: 0.05, score: 43
# Scores: (min: 8, avg: 12.53, max: 96)
#
# Run: 555, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 12.75, max: 96)
#
# Run: 556, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 12.86, max: 96)
#
# Run: 557, exploration: 0.05, score: 27
# Scores: (min: 8, avg: 13.04, max: 96)
#
# Run: 558, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 13.07, max: 96)
#
# Run: 559, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 13.1, max: 96)
#
# Run: 560, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 13.25, max: 96)
#
# Run: 561, exploration: 0.05, score: 23
# Scores: (min: 8, avg: 13.4, max: 96)
#
# Run: 562, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 13.56, max: 96)
#
# Run: 563, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 13.67, max: 96)
#
# Run: 564, exploration: 0.05, score: 46
# Scores: (min: 8, avg: 14.05, max: 96)
#
# Run: 565, exploration: 0.05, score: 32
# Scores: (min: 8, avg: 14.28, max: 96)
#
# Run: 566, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.29, max: 96)
#
# Run: 567, exploration: 0.05, score: 24
# Scores: (min: 8, avg: 14.44, max: 96)
#
# Run: 568, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.44, max: 96)
#
# Run: 569, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 14.47, max: 96)
#
# Run: 570, exploration: 0.05, score: 47
# Scores: (min: 8, avg: 14.85, max: 96)
#
# Run: 571, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 14.86, max: 96)
#
# Run: 572, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.88, max: 96)
#
# Run: 573, exploration: 0.05, score: 10
# Scores: (min: 8, avg: 14.88, max: 96)
#
# Run: 574, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 15, max: 96)
#
# Run: 575, exploration: 0.05, score: 19
# Scores: (min: 8, avg: 15.08, max: 96)
#
# Run: 576, exploration: 0.05, score: 31
# Scores: (min: 8, avg: 15.3, max: 96)
#
# Run: 577, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 15.37, max: 96)
#
# Run: 578, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 15.47, max: 96)
#
# Run: 579, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 15.58, max: 96)
#
# Run: 580, exploration: 0.05, score: 25
# Scores: (min: 8, avg: 15.74, max: 96)
#
# Run: 581, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 15.78, max: 96)
#
# Run: 582, exploration: 0.05, score: 22
# Scores: (min: 8, avg: 15.89, max: 96)
#
# Run: 583, exploration: 0.05, score: 21
# Scores: (min: 8, avg: 16, max: 96)
#
# Run: 584, exploration: 0.05, score: 125
# Scores: (min: 8, avg: 17.15, max: 125)
#
# Run: 585, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 17.18, max: 125)
#
# Run: 586, exploration: 0.05, score: 51
# Scores: (min: 8, avg: 17.59, max: 125)
#
# Run: 587, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 17.62, max: 125)
#
# Run: 588, exploration: 0.05, score: 12
# Scores: (min: 8, avg: 17.63, max: 125)
#
# Run: 589, exploration: 0.05, score: 13
# Scores: (min: 8, avg: 17.66, max: 125)
#
# Run: 590, exploration: 0.05, score: 17
# Scores: (min: 8, avg: 17.69, max: 125)
#
# Run: 591, exploration: 0.05, score: 15
# Scores: (min: 8, avg: 17.74, max: 125)
#
# Run: 592, exploration: 0.05, score: 9
# Scores: (min: 8, avg: 17.74, max: 125)
#
# Run: 593, exploration: 0.05, score: 14
# Scores: (min: 8, avg: 17.78, max: 125)
#
# ...
#
# Run: 2574, exploration: 0.05, score: 47
# Scores: (min: 11, avg: 75.67, max: 190)
#
# Run: 2575, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 75.87, max: 190)
#
# Run: 2576, exploration: 0.05, score: 35
# Scores: (min: 11, avg: 75.2, max: 190)
#
# Run: 2577, exploration: 0.05, score: 21
# Scores: (min: 11, avg: 74.09, max: 190)
#
# Run: 2578, exploration: 0.05, score: 143
# Scores: (min: 11, avg: 74.57, max: 190)
#
# Run: 2579, exploration: 0.05, score: 130
# Scores: (min: 11, avg: 75.15, max: 190)
#
# Run: 2580, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 75.05, max: 190)
#
# Run: 2581, exploration: 0.05, score: 234
# Scores: (min: 11, avg: 77.06, max: 234)
#
# Run: 2582, exploration: 0.05, score: 88
# Scores: (min: 11, avg: 77.22, max: 234)
#
# Run: 2583, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 76.91, max: 234)
#
# Run: 2584, exploration: 0.05, score: 39
# Scores: (min: 11, avg: 76.33, max: 234)
#
# Run: 2585, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 76.81, max: 234)
#
# Run: 2586, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 76.19, max: 234)
#
# Run: 2587, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 76.25, max: 234)
#
# Run: 2588, exploration: 0.05, score: 31
# Scores: (min: 11, avg: 75.6, max: 234)
#
# Run: 2589, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 75, max: 234)
#
# Run: 2590, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 74.26, max: 234)
#
# Run: 2591, exploration: 0.05, score: 29
# Scores: (min: 11, avg: 73.43, max: 234)
#
# Run: 2592, exploration: 0.05, score: 31
# Scores: (min: 11, avg: 72.8, max: 234)
#
# Run: 2593, exploration: 0.05, score: 56
# Scores: (min: 11, avg: 72.46, max: 234)
#
# Run: 2594, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 72.43, max: 234)
#
# Run: 2595, exploration: 0.05, score: 163
# Scores: (min: 11, avg: 73.74, max: 234)
#
# Run: 2596, exploration: 0.05, score: 51
# Scores: (min: 11, avg: 73.68, max: 234)
#
# Run: 2597, exploration: 0.05, score: 106
# Scores: (min: 11, avg: 73.85, max: 234)
#
# Run: 2598, exploration: 0.05, score: 33
# Scores: (min: 11, avg: 73.17, max: 234)
#
# Run: 2599, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 73.85, max: 234)
#
# Run: 2600, exploration: 0.05, score: 67
# Scores: (min: 11, avg: 73.59, max: 234)
#
# Run: 2601, exploration: 0.05, score: 87
# Scores: (min: 11, avg: 74.27, max: 234)
#
# Run: 2602, exploration: 0.05, score: 44
# Scores: (min: 11, avg: 74.49, max: 234)
#
# Run: 2603, exploration: 0.05, score: 81
# Scores: (min: 11, avg: 74.27, max: 234)
#
# Run: 2604, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 74.33, max: 234)
#
# Run: 2605, exploration: 0.05, score: 60
# Scores: (min: 11, avg: 73.92, max: 234)
#
# Run: 2606, exploration: 0.05, score: 49
# Scores: (min: 11, avg: 74.07, max: 234)
#
# Run: 2607, exploration: 0.05, score: 152
# Scores: (min: 11, avg: 74.53, max: 234)
#
# Run: 2608, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 74.17, max: 234)
#
# Run: 2609, exploration: 0.05, score: 162
# Scores: (min: 11, avg: 75.01, max: 234)
#
# Run: 2610, exploration: 0.05, score: 39
# Scores: (min: 11, avg: 75.22, max: 234)
#
# Run: 2611, exploration: 0.05, score: 83
# Scores: (min: 11, avg: 74.15, max: 234)
#
# Run: 2612, exploration: 0.05, score: 109
# Scores: (min: 11, avg: 74.33, max: 234)
#
# Run: 2613, exploration: 0.05, score: 19
# Scores: (min: 11, avg: 73.66, max: 234)
#
# Run: 2614, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 73.6, max: 234)
#
# Run: 2615, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 71.97, max: 234)
#
# Run: 2616, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 72.1, max: 234)
#
# Run: 2617, exploration: 0.05, score: 93
# Scores: (min: 11, avg: 72.7, max: 234)
#
# Run: 2618, exploration: 0.05, score: 118
# Scores: (min: 11, avg: 73.25, max: 234)
#
# Run: 2619, exploration: 0.05, score: 68
# Scores: (min: 11, avg: 73.04, max: 234)
#
# Run: 2620, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 73.16, max: 234)
#
# Run: 2621, exploration: 0.05, score: 73
# Scores: (min: 11, avg: 73.34, max: 234)
#
# Run: 2622, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 72.55, max: 234)
#
# Run: 2623, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 71.66, max: 234)
#
# Run: 2624, exploration: 0.05, score: 30
# Scores: (min: 11, avg: 70.97, max: 234)
#
# Run: 2625, exploration: 0.05, score: 56
# Scores: (min: 11, avg: 70.63, max: 234)
#
# Run: 2626, exploration: 0.05, score: 65
# Scores: (min: 11, avg: 70.39, max: 234)
#
# Run: 2627, exploration: 0.05, score: 130
# Scores: (min: 11, avg: 70.71, max: 234)
#
# Run: 2628, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 71.51, max: 234)
#
# Run: 2629, exploration: 0.05, score: 52
# Scores: (min: 11, avg: 70.23, max: 234)
#
# Run: 2630, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 69.53, max: 234)
#
# Run: 2631, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 69.5, max: 234)
#
# Run: 2632, exploration: 0.05, score: 23
# Scores: (min: 11, avg: 69.31, max: 234)
#
# Run: 2633, exploration: 0.05, score: 103
# Scores: (min: 11, avg: 70, max: 234)
#
# Run: 2634, exploration: 0.05, score: 98
# Scores: (min: 11, avg: 70.59, max: 234)
#
# Run: 2635, exploration: 0.05, score: 121
# Scores: (min: 11, avg: 71.41, max: 234)
#
# Run: 2636, exploration: 0.05, score: 34
# Scores: (min: 11, avg: 71.56, max: 234)
#
# Run: 2637, exploration: 0.05, score: 22
# Scores: (min: 11, avg: 71.65, max: 234)
#
# Run: 2638, exploration: 0.05, score: 16
# Scores: (min: 11, avg: 71.7, max: 234)
#
# Run: 2639, exploration: 0.05, score: 17
# Scores: (min: 11, avg: 71.6, max: 234)
#
# Run: 2640, exploration: 0.05, score: 72
# Scores: (min: 11, avg: 72.16, max: 234)
#
# Run: 2641, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 72.98, max: 234)
#
# Run: 2642, exploration: 0.05, score: 33
# Scores: (min: 11, avg: 73.18, max: 234)
#
# Run: 2643, exploration: 0.05, score: 76
# Scores: (min: 11, avg: 73.24, max: 234)
#
# Run: 2644, exploration: 0.05, score: 84
# Scores: (min: 11, avg: 73.79, max: 234)
#
# Run: 2645, exploration: 0.05, score: 20
# Scores: (min: 11, avg: 73.63, max: 234)
#
# Run: 2646, exploration: 0.05, score: 100
# Scores: (min: 11, avg: 73.56, max: 234)
#
# Run: 2647, exploration: 0.05, score: 45
# Scores: (min: 11, avg: 73.32, max: 234)
#
# Run: 2648, exploration: 0.05, score: 92
# Scores: (min: 11, avg: 73.06, max: 234)
#
# Run: 2649, exploration: 0.05, score: 102
# Scores: (min: 11, avg: 72.77, max: 234)
#
# Run: 2650, exploration: 0.05, score: 117
# Scores: (min: 11, avg: 73.73, max: 234)
#
# Run: 2651, exploration: 0.05, score: 105
# Scores: (min: 11, avg: 73.96, max: 234)
#
# Run: 2652, exploration: 0.05, score: 26
# Scores: (min: 11, avg: 74.1, max: 234)
#
# Run: 2653, exploration: 0.05, score: 43
# Scores: (min: 11, avg: 73.09, max: 234)
#
# Run: 2654, exploration: 0.05, score: 91
# Scores: (min: 11, avg: 72.85, max: 234)
#
# Run: 2655, exploration: 0.05, score: 53
# Scores: (min: 11, avg: 72.69, max: 234)
#
# Run: 2656, exploration: 0.05, score: 36
# Scores: (min: 11, avg: 72.04, max: 234)
#
# Run: 2657, exploration: 0.05, score: 256
# Scores: (min: 11, avg: 73.55, max: 256)
#
# Run: 2658, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 73.66, max: 256)
#
# Run: 2659, exploration: 0.05, score: 71
# Scores: (min: 11, avg: 73.99, max: 256)
#
# Run: 2660, exploration: 0.05, score: 138
# Scores: (min: 11, avg: 75.18, max: 256)
#
# Run: 2661, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 74.88, max: 256)
#
# Run: 2662, exploration: 0.05, score: 45
# Scores: (min: 11, avg: 75.07, max: 256)
#
# Run: 2663, exploration: 0.05, score: 13
# Scores: (min: 11, avg: 74.88, max: 256)
#
# Run: 2664, exploration: 0.05, score: 71
# Scores: (min: 11, avg: 74.18, max: 256)
# Run: 2665, exploration: 0.05, score: 129
# Scores: (min: 11, avg: 74.4, max: 256)
#
# Run: 2666, exploration: 0.05, score: 53
# Scores: (min: 11, avg: 74.07, max: 256)
#
# Run: 2667, exploration: 0.05, score: 124
# Scores: (min: 11, avg: 74.73, max: 256)
#
# Run: 2668, exploration: 0.05, score: 113
# Scores: (min: 11, avg: 74.87, max: 256)
#
# Run: 2669, exploration: 0.05, score: 18
# Scores: (min: 11, avg: 74.87, max: 256)
#
# Run: 2670, exploration: 0.05, score: 61
# Scores: (min: 11, avg: 74.9, max: 256)
#
# Run: 2671, exploration: 0.05, score: 78
# Scores: (min: 11, avg: 75.31, max: 256)
#
# Run: 2672, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 74.92, max: 256)
#
# Run: 2673, exploration: 0.05, score: 17
# Scores: (min: 11, avg: 74.12, max: 256)
#
# Run: 2674, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 74.73, max: 256)
#
# Run: 2675, exploration: 0.05, score: 90
# Scores: (min: 11, avg: 74.6, max: 256)
#
# Run: 2676, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 74.36, max: 256)
#
# Run: 2677, exploration: 0.05, score: 77
# Scores: (min: 11, avg: 74.92, max: 256)
#
# Run: 2678, exploration: 0.05, score: 70
# Scores: (min: 11, avg: 74.19, max: 256)
#
# Run: 2679, exploration: 0.05, score: 76
# Scores: (min: 11, avg: 73.65, max: 256)
#
# Run: 2680, exploration: 0.05, score: 18
# Scores: (min: 11, avg: 72.75, max: 256)
#
# Run: 2681, exploration: 0.05, score: 22
# Scores: (min: 11, avg: 70.63, max: 256)
#
# Run: 2682, exploration: 0.05, score: 37
# Scores: (min: 11, avg: 70.12, max: 256)
#
# Run: 2683, exploration: 0.05, score: 11
# Scores: (min: 11, avg: 69.15, max: 256)
#
# Run: 2684, exploration: 0.05, score: 61
# Scores: (min: 11, avg: 69.37, max: 256)
#
# Run: 2685, exploration: 0.05, score: 58
# Scores: (min: 11, avg: 69.01, max: 256)
#
# Run: 2686, exploration: 0.05, score: 95
# Scores: (min: 11, avg: 69.53, max: 256)
#
# Run: 2687, exploration: 0.05, score: 112
# Scores: (min: 11, avg: 69.66, max: 256)
#
# Run: 2688, exploration: 0.05, score: 114
# Scores: (min: 11, avg: 70.49, max: 256)
#
# Run: 2689, exploration: 0.05, score: 68
# Scores: (min: 11, avg: 70.88, max: 256)
#
# Run: 2690, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 71.86, max: 256)
#
# Run: 2691, exploration: 0.05, score: 25
# Scores: (min: 11, avg: 71.82, max: 256)
#
# Run: 2692, exploration: 0.05, score: 126
# Scores: (min: 11, avg: 72.77, max: 256)
#
# Run: 2693, exploration: 0.05, score: 38
# Scores: (min: 11, avg: 72.59, max: 256)
#
# Run: 2694, exploration: 0.05, score: 80
# Scores: (min: 11, avg: 72.45, max: 256)
#
# Run: 2695, exploration: 0.05, score: 94
# Scores: (min: 11, avg: 71.76, max: 256)
#
# Run: 2696, exploration: 0.05, score: 108
# Scores: (min: 11, avg: 72.33, max: 256)
#
# Run: 2697, exploration: 0.05, score: 13
# Scores: (min: 11, avg: 71.4, max: 256)
#
# Run: 2698, exploration: 0.05, score: 125
# Scores: (min: 11, avg: 72.32, max: 256)
#
# Run: 2699, exploration: 0.05, score: 75
# Scores: (min: 11, avg: 72.17, max: 256)
#
# Run: 2700, exploration: 0.05, score: 113
# Scores: (min: 11, avg: 72.63, max: 256)
#
# Run: 2701, exploration: 0.05, score: 67
# Scores: (min: 11, avg: 72.43, max: 256)
#
# Run: 2702, exploration: 0.05, score: 21
# Scores: (min: 11, avg: 72.2, max: 256)
#
# Run: 2703, exploration: 0.05, score: 127
# Scores: (min: 11, avg: 72.66, max: 256)
#
# Run: 2704, exploration: 0.05, score: 12
# Scores: (min: 11, avg: 71.76, max: 256)
#
# Run: 2705, exploration: 0.05, score: 100
# Scores: (min: 11, avg: 72.16, max: 256)
#
# Run: 2706, exploration: 0.05, score: 14
# Scores: (min: 11, avg: 71.81, max: 256)
#
# Run: 2707, exploration: 0.05, score: 18
# Scores: (min: 11, avg: 70.47, max: 256)
#
# Run: 2708, exploration: 0.05, score: 40
# Scores: (min: 11, avg: 69.93, max: 256)
#
# Run: 2709, exploration: 0.05, score: 134
# Scores: (min: 11, avg: 69.65, max: 256)
#
# Run: 2710, exploration: 0.05, score: 46
# Scores: (min: 11, avg: 69.72, max: 256)
#
# Run: 2711, exploration: 0.05, score: 31
# Scores: (min: 11, avg: 69.2, max: 256)
#
# Run: 2712, exploration: 0.05, score: 128
# Scores: (min: 11, avg: 69.39, max: 256)
#
# Run: 2713, exploration: 0.05, score: 27
# Scores: (min: 11, avg: 69.47, max: 256)
#
# Run: 2714, exploration: 0.05, score: 69
# Scores: (min: 11, avg: 69.32, max: 256)
#
# Run: 2715, exploration: 0.05, score: 99
# Scores: (min: 11, avg: 70.19, max: 256)
#
# Run: 2716, exploration: 0.05, score: 109
# Scores: (min: 11, avg: 70.34, max: 256)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-dd9109d9550e> in <module>
#       6 EXPLORATION_DECAY = 0.8
#       7
# ----> 8 cartpole()
#
# <ipython-input-3-bea6327a4fd8> in cartpole()
#      86                 score_logger.add_score(step, run)
#      87                 break
# ---> 88             dqn_solver.experience_replay()
#      89
#
# <ipython-input-3-bea6327a4fd8> in experience_replay(self)
#      56             q_values = self.model.predict(state)
#      57             q_values[0][action] = q_update
# ---> 58             self.model.fit(state, q_values, verbose=0)
#      59         self.exploration_rate *= EXPLORATION_DECAY
#      60         self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#    1237                                         steps_per_epoch=steps_per_epoch,
#    1238                                         validation_steps=validation_steps,
# -> 1239                                         validation_freq=validation_freq)
#    1240
#    1241     def evaluate(self,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, fit_function, fit_inputs, out_labels, batch_size, epochs, verbose, callbacks, val_function, val_inputs, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq)
#     194                     ins_batch[i] = ins_batch[i].toarray()
#     195
# --> 196                 outs = fit_function(ins_batch)
#     197                 outs = to_list(outs)
#     198                 for l, o in zip(out_labels, outs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# - Explain how reinforcement learning concepts apply to the cartpole problem
#
# The goal of the agent in the cartpole problem is to keep the pole pointed upwards even though it is unstable.  The states in this case are the results of actions by the cart on the pole.  The cart can move left or right to keep it balanced which may make it centered or contribute to it falling over.  The learning algorithm used to train the cart to keep the pole upright is the Deep Q-Learning technique (DQN).
#
# - Analyze how experience replay is applied to the cartpole problem
#
# Experience replay is a process used that samples actions and updates its related Q-value.  Q-values are measures of quality for a given move.  So by trying different moves at different states, the Q-values can be updated accordingly to find on average the best actions for a given problem.  The discount factor is woven into this as a way to simulate uncertainty.  Actions that have more risk should have a discounted reward to the agent since there is a chance that they may not receive the reward.  An example of this is why most people will not spend all of their money on a power ball ticket.  The perceived risk of spending all of your money is much greater than the likelihood of actually winning, making that action less likely to be acted on.
#
# - Analyze how neural networks are used in deep Q-learning.
#
# Deep Q-learning is different than Q-learning in that the first approximates the values in the Q table while the other calculates them manually.  The benefits of the neural network are the lesser memory requirements of continuous or large sets.  The neural network is setup in that the inputs are states with the output being pairs of actions and q-values.  The output with the highest q-values represent the best known actions for that state.  The learning rate is used to update the weights in the neural network after each run.  Instead of updating the weight by the full amount, the difference is multiplied by the learning weight and added to the current amount.  Increasing or lowering this hyper parameter than can effect the rate of change of the weights in the model.
#
# Sources:
#
# 1. Beysolow, I. T. (2019). Applied reinforcement learning with python : With openai gym, tensorflow, and keras. Apress L. P..
#
# 2. Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium. Retrieved November 21, 2021, from https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288.
#
# 3. Wang, M. (2021, October 3). Deep Q-learning tutorial: Mindqn. Medium. Retrieved November 21, 2021, from https://towardsdatascience.com/deep-q-learning-tutorial-mindqn-2a4c855abffc.
